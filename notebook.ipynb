# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Load the interbank exposures matrix
exposures = pd.read_csv('interbankExposures.csv', header=None).values

# %%
import pandas as pd


# Read the CSV file into a DataFrame
# Replace 'exposures.csv' with the path to your CSV file
df = pd.read_csv('interbankExposures.csv', header = None)

# Create a directed graph from the adjacency matrix
G = nx.from_pandas_adjacency(df, create_using=nx.DiGraph)

# Calculate topological properties
global_clustering_coefficient = nx.average_clustering(G)
degree_sequence = [d for n, d in G.degree()]
link_density = nx.density(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G)

# Print results
print(f'Global Clustering Coefficient: {global_clustering_coefficient}')
print(f'Degree Distribution: {degree_sequence}')
print(f'Link Density: {link_density}')
print(f'Betweenness Centrality: {betweenness_centrality}')
print(f'Closeness Centrality: {closeness_centrality}')
print(f'Eigenvector Centrality: {eigenvector_centrality}')

#print the number of nodes and edges in the network
print('Number of nodes: ', G.number_of_nodes())
print('Number of edges: ', G.number_of_edges())
# Out:
# Global Clustering Coefficient: 0.7330779611675567
# Degree Distribution: [16, 2, 5, 217, 45, 48, 137, 214, 46, 45, 51, 54, 64, 167, 42, 55, 8, 73, 78, 39, 127, 92, 65, 2, 94, 47, 41, 216, 46, 149, 11, 171, 68, 68, 177, 31, 78, 77, 3, 214, 50, 7, 17, 92, 24, 119, 49, 149, 162, 15, 101, 87, 65, 99, 196, 71, 21, 18, 58, 204, 176, 93, 167, 45, 56, 92, 30, 115, 96, 72, 31, 137, 209, 82, 21, 11, 82, 59, 154, 193, 80, 11, 241, 209, 80, 189, 150, 74, 87, 18, 44, 49, 80, 125, 29, 91, 74, 74, 172, 68, 84, 66, 87, 53, 85, 59, 54, 5, 101, 141, 76, 118, 38, 38, 48, 53, 189, 14, 38, 30, 199, 53, 214, 43, 78, 62, 24, 68, 225, 114, 50, 105, 77, 42, 22, 17, 163, 26, 84, 7, 200, 209, 39, 74, 157]
# Link Density: 0.29650383141762454
# ...

# %%
#plot the degree distribution of the network
plt.hist(degree_sequence, bins=50)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.show()
